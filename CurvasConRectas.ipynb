# %%
import warnings
from search import Problem
from search import depth_limited_search
warnings.filterwarnings("ignore")
import operator
import math

def add_tuples(a, b):
    return operate_on_tuples(a, b, operator.add)


def subtract_tuples(a, b):
    return operate_on_tuples(a, b, operator.sub)


def operate_on_tuples(a, b, operation):
    return tuple(map(operation, a, b))


def contains_negative(collection):
    """Return True if any negative value exists in the collection."""
    return any(n < 0 for n in collection)

# %%
class Trenecito(Problem):
    
    def __init__(self):
        self.initial_state = State.value_of(INITIAL_STATE)
        self.goal_state = State.value_of(GOAL_STATE)
        super().__init__(self.initial_state, self.goal_state) 
        
    def actions(self, state):
        return ['ponerR','ponerCI','ponerCD']    

    def result(self, state, action):
        coordx = state.coordx
        coordy = state.coordy
        rectas = state.rectas
        curvas = state.curvas
        muescas = state.muescas
        pestañas = state.pestañas
        orientacion = state.orientacion
        seq = state.seq
        next_state =  State(coordx,coordy,rectas,curvas,muescas,pestañas,orientacion,seq)
        
        if orientacion == "N":  #NORTE
            if action == "ponerR" and state.rectas!=0 :  
              #  seq.append("R")
                next_state.coordy = next_state.coordy + 1 
                next_state.rectas = next_state.rectas - 1            
            
            elif action == "ponerCI" and state.curvas!=0 :
              #  next_state.seq.append("CI")
                next_state.coordx = next_state.coordx - 1
                next_state.coordy = next_state.coordy + 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "NO"
                
            elif action == "ponerCD"and state.curvas!=0 :
              #  next_state.seq.append("CD")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy + 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "NE"
                
        elif orientacion == "S" :   #SUR
            if action == "ponerR" and state.rectas!=0 :  
             #   seq.append("R")
                next_state.coordy = next_state.coordy - 1 
                next_state.rectas = next_state.rectas - 1
                    
            elif action == "ponerCI" and state.curvas!=0:
             #   next_state.seq.append("CI")
                next_state.coordx = next_state.coordx + 1 
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "SE"
                
            elif action == "ponerCD" and state.curvas!=0:
              #  next_state.seq.append("CD")
                next_state.coordx = next_state.coordx - 1  
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "SE"

                
        elif orientacion == "E": #ESTE
            if action == "ponerR" and state.rectas!=0:  
             #   seq.append("R")
                next_state.coordx = next_state.coordx + 1  
                next_state.rectas = next_state.rectas - 1
                
            elif action == "ponerCI" and state.curvas!=0:
              #  next_state.seq.append("CI")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy + 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "NE"
                
            elif action == "ponerCD" and state.curvas!=0:
             #   next_state.seq.append("CD")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "SE"
                
        elif orientacion == "O":  #OESTE
            
            if action == "ponerR" and state.rectas!=0:  
              #  seq.append("R")
                next_state.coordx = next_state.coordx - 1  
                next_state.rectas = next_state.rectas - 1  
                
            elif action == "ponerCI" and state.curvas!=0:
             #   next_state.seq.append("CI")
                next_state.coordx = next_state.coordx - 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "SO"
                
            elif action == "ponerCD" and state.curvas!=0:
             #   next_state.seq.append("CD")
                next_state.coordx = next_state.coordx - 1
                next_state.coordy = next_state.coordy + 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "NO"
              
                
        elif orientacion == "NE":  #NORESTE    
            
            if action == "ponerR" and state.rectas!=0:  
             #   seq.append("R")
                next_state.coordx = next_state.coordx + 1  
                next_state.coordy = next_state.coordy + 1
                next_state.rectas = next_state.rectas - 1       
                
            elif action == "ponerCI" and state.curvas!=0 :
             #   next_state.seq.append("CI")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy + 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "N"
                
            elif action == "ponerCD" and state.curvas!=0:
             #   next_state.seq.append("CD")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "E"
                
                
        elif orientacion == "NO":  #NOROESTE   
            
            if action == "ponerR" and state.rectas!=0:  
               # seq.append("R")
                next_state.coordx = next_state.coordx - 1  
                next_state.coordy = next_state.coordy + 1
                next_state.rectas = next_state.rectas - 1
                
            elif action == "ponerCI" and state.curvas!=0:
               # next_state.seq.append("CI")
                next_state.coordx = next_state.coordx - 1
                next_state.coordy = next_state.coordy + 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "O"
                
            elif action == "ponerCD" and state.curvas!=0:
                #next_state.seq.append("CD")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "E"

                
        elif orientacion == "SE":  #SURESTE
            
            if action == "ponerR" and state.rectas!=0:  
                #seq.append("R")
                next_state.coordx = next_state.coordx + 1  
                next_state.coordy = next_state.coordy - 1
                next_state.rectas = next_state.rectas - 1
                
            elif action == "ponerCI" and state.curvas!=0:
               # next_state.seq.append("CI")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "E"
                
            elif action == "ponerCD" and state.curvas!=0:
              #  next_state.seq.append("CD")
                next_state.coordx = next_state.coordx + 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "S"  
                
                
        elif orientacion == "SO":  #SUROESTE
            
            if action == "ponerR" and state.rectas!=0:  
             #   seq.append("R")
                next_state.coordx = next_state.coordx - 1  
                next_state.coordy = next_state.coordy - 1
                next_state.rectas = next_state.rectas - 1
                
            elif action == "ponerCI" and state.curvas!=0 :
               
            #next_state.seq.append("CI")
                next_state.coordx = next_state.coordx - 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "S"
                
            elif action == "ponerCD" and state.curvas!=0:
               # next_state.seq.append("CD")
                next_state.coordx = next_state.coordx - 1
                next_state.coordy = next_state.coordy - 1
                next_state.curvas = next_state.curvas - 1
                next_state.orientacion = "O"
            
        return next_state
                
    def goal_test(self, state):
        if isinstance(self.goal, list):
            return state in self.goal  
        else:
            return state == self.goal  
    def path_cost(self, cost, state1, action, state2):
        return cost+1

# %%
class State:
    orientacion = ""
    def __init__(self,coordx,coordy,rectas,curvas,muescas,pestañas,orientacion,seq):
        self.value = (coordx,coordy,rectas,curvas,muescas,pestañas,orientacion,seq)
        self.coordx = coordx
        self.coordy = coordy
        self.rectas = rectas
        self.curvas = curvas
        self.muescas = muescas
        self.pestañas= pestañas
        self.orientacion = orientacion
        self.seq = seq
        
    @classmethod
    def value_of(cls, state):
        if not cls.__is_valid_tuple(state):
            raise ValueError(str(state) + " must be a tuple with 8 elements.")
        return State(state[0], state[1], state[2], state[3], state[4], state[5],state[6],state[7])

    def is_valid(self):
        if contains_negative(self.value):
            return False
        else:
            return True
    
    @staticmethod
    def __is_valid_tuple(other):
        return isinstance(other, tuple) and len(other) == 8

    @staticmethod
    def __get_invalid_operand_error(other):
        return str(other) + " must be an instance of State or a tuple of length 8."

    def __repr__(self):
        return '<State {}>'.format(self.value)

    def __str__(self):
        return '<State {}>'.format(self.value)

    def __lt__(self, other):
        self.__ensure_instance_of_state(other)
        return self.value < other.value

    def __eq__(self, other):
        return isinstance(other, State) and self.value == other.value

    def __hash__(self):
        return hash(self.value)

    @staticmethod
    def __ensure_instance_of_state(other):
        if not isinstance(other, State):
            raise ValueError(str(other) + " must be an instance of State")

# %%
seq=[]
INITIAL_STATE = (0,0,2,8,1,1,"E",seq)
GOAL_STATE =    (0,0,0,0,1,1,"E",seq)

# %%
from search import iterative_deepening_search

def print_path(path):
    for node in path:
        print(node.state.value)

Tren = Trenecito()
#result = iterative_deepening_search(Tren)
result2 = depth_limited_search(Tren, limit=20)
print_path(result2.path())
# Out:
# (0, 0, 2, 8, 1, 1, 'E', [])
# (0, 0, 2, 8, 1, 1, 'E', [])
# (1, 0, 1, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (2, 0, 0, 8, 1, 1, 'E', [])
# (3, 1, 0, 7, 1, 1, 'NE', [])
# (4, 2, 0, 6, 1, 1, 'N', [])
# (3, 3, 0, 5, 1, 1, 'NO', [])
# (2, 4, 0, 4, 1, 1, 'O', [])
# (1, 3, 0, 3, 1, 1, 'SO', [])
# (0, 2, 0, 2, 1, 1, 'S', [])
# (-1, 1, 0, 1, 1, 1, 'SE', [])
# (0, 0, 0, 0, 1, 1, 'E', [])
